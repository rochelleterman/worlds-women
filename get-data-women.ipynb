# %%
from nytimesarticle import articleAPI

# %%
api = articleAPI('e15cea455f73cc47d6d971667e09c31c:19:44644296')

# %%
articles = api.search( q = 'women', fq = {'source':['Reuters','AP', 'The New York Times'],'subject.contains':'women'}, begin_date = 19801231, facet_field = ['source'], facet_filter = True )

# %%
articles
# Out:
# {u'copyright': u'Copyright (c) 2013 The New York Times Company.  All Rights Reserved.',
#  u'response': {u'docs': [{u'_id': u'54d4ce547988104052672a42',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'original': u'By ADAM GRANT and SHERYL SANDBERG',
#      u'person': [{u'firstname': u'Adam',
#        u'lastname': u'GRANT',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'},
#       {u'firstname': u'Sheryl',
#        u'lastname': u'SANDBERG',
#        u'organization': u'',
#        u'rank': 2,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'content_kicker': u'Women at Work',
#      u'kicker': u'Women at Work',
#      u'main': u'Madam C.E.O., Get Me a Coffee',
#      u'print_headline': u'Madame C.E.O., Get Me a Coffee',
#      u'seo': u'Sheryl Sandberg and Adam Grant on Women Doing &#8216;Office Housework&#8217;'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Women and Girls'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Careers and Professions'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Discrimination'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Men and Boys'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'5',
#       u'value': u'New York University'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'6',
#       u'value': u'Psychology and Psychologists'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'7',
#       u'value': u'Executives and Management (Theory)'}],
#     u'lead_paragraph': u'The sad reality in workplaces: Women help more but benefit less from it.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/02/08/sunday-review/08women-profile/08women-profile-thumbWide-v3.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/02/08/sunday-review/08women-profile/08women-profile-thumbWide-v3.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2015/02/08/sunday-review/08women-profile/08women-profile-articleLarge-v2.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/02/08/sunday-review/08women-profile/08women-profile-articleLarge-v2.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/02/08/sunday-review/08women-profile/08women-profile-thumbStandard-v2.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/02/08/sunday-review/08women-profile/08women-profile-thumbStandard-v2.jpg',
#       u'width': 75}],
#     u'news_desk': u'OpEd',
#     u'print_page': None,
#     u'pub_date': u'2015-02-08T00:00:00Z',
#     u'section_name': u'Opinion',
#     u'snippet': u'The sad reality in workplaces: Women help more but benefit less from it.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Sunday Review',
#     u'type_of_material': u'Op-Ed',
#     u'web_url': u'http://www.nytimes.com/2015/02/08/opinion/sunday/sheryl-sandberg-and-adam-grant-on-women-doing-office-housework.html',
#     u'word_count': u'1127'},
#    {u'_id': u'54b3e27c79881019b02c32ea',
#     u'abstract': u'Women at Work column by Sheryl Sandberg, chief operating officer of Facebook, and Prof Adam Grant examines research showing that women speak their minds less often in work settings because they are either ignored or punished for speaking up; suggests that it is up to leaders to find ways to encourage women to speak up and for their voices to be heard.',
#     u'blog': [],
#     u'byline': {u'contributor': u'',
#      u'original': u'By SHERYL SANDBERG and ADAM GRANT',
#      u'person': [{u'firstname': u'Sheryl',
#        u'lastname': u'SANDBERG',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'},
#       {u'firstname': u'Adam',
#        u'lastname': u'GRANT',
#        u'organization': u'',
#        u'rank': 2,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'content_kicker': u'Women at Work',
#      u'kicker': u'Women at Work',
#      u'main': u'Speaking While Female ',
#      u'print_headline': u'Speaking While Female',
#      u'seo': u'Sheryl Sandberg and Adam Grant on Why Women Stay Quiet at Work'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Women and Girls'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Workplace Environment'}],
#     u'lead_paragraph': u'If a man talks in a meeting, he gets heard. A woman just gets interrupted.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/11/sunday-review/11WOMEN/11WOMEN-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/11/sunday-review/11WOMEN/11WOMEN-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 475,
#       u'legacy': {u'xlarge': u'images/2015/01/11/sunday-review/11WOMEN/11WOMEN-articleLarge.jpg',
#        u'xlargeheight': u'475',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/11/sunday-review/11WOMEN/11WOMEN-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/11/sunday-review/11WOMEN/11WOMEN-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/11/sunday-review/11WOMEN/11WOMEN-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'OpEd',
#     u'print_page': None,
#     u'pub_date': u'2015-01-11T00:00:00Z',
#     u'section_name': u'Opinion',
#     u'snippet': u'If a man talks in a meeting, he gets heard. A woman just gets interrupted.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Sunday Review',
#     u'type_of_material': u'Op-Ed',
#     u'web_url': u'http://www.nytimes.com/2015/01/11/opinion/sunday/speaking-while-female.html',
#     u'word_count': u'894'},
#    {u'_id': u'54838a8d7988106fd483c9b0',
#     u'abstract': u"Women at Work column by Prof Adam Grant and Sheryl Sandberg, chief operating officer of Facebook, contends American culture's strong gender stereotypes extend beyond image to performance and lead many to believe men are more competent than women; highlights research that shows learning about ubiquity of stereotypes only makes stereotyping worse, unless people are encouraged to correct their biases.",
#     u'blog': [],
#     u'byline': {u'contributor': u'',
#      u'original': u'By ADAM GRANT and SHERYL SANDBERG',
#      u'person': [{u'firstname': u'Adam',
#        u'lastname': u'GRANT',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'},
#       {u'firstname': u'Sheryl',
#        u'lastname': u'SANDBERG',
#        u'organization': u'',
#        u'rank': 2,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'content_kicker': u'Women at Work',
#      u'kicker': u'Women at Work',
#      u'main': u'When Talking About Bias Backfires',
#      u'print_headline': u'When Talking About Bias Backfires',
#      u'seo': u'Adam Grant and Sheryl Sandberg on Discrimination at Work'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'1',
#       u'value': u'United States'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Women and Girls'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Discrimination'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Social Conditions and Trends'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Gender'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'6',
#       u'value': u'Hiring and Promotion'}],
#     u'lead_paragraph': u'Hearing that discrimination is common is a license to do it.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2014/12/07/sunday-review/07women/07women-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2014/12/07/sunday-review/07women/07women-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 492,
#       u'legacy': {u'xlarge': u'images/2014/12/07/sunday-review/07women/07women-articleLarge.jpg',
#        u'xlargeheight': u'492',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2014/12/07/sunday-review/07women/07women-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2014/12/07/sunday-review/07women/07women-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2014/12/07/sunday-review/07women/07women-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'OpEd',
#     u'print_page': None,
#     u'pub_date': u'2014-12-07T00:00:00Z',
#     u'section_name': u'Opinion',
#     u'snippet': u'Hearing that discrimination is common is a license to do it.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Sunday Review',
#     u'type_of_material': u'Op-Ed',
#     u'web_url': u'http://www.nytimes.com/2014/12/07/opinion/sunday/adam-grant-and-sheryl-sandberg-on-discrimination-at-work.html',
#     u'word_count': u'1103'},
#    {u'_id': u'5499e8387988102d96d54fcf',
#     u'abstract': u'National Museum of Women in the Arts, in Washington, will be first American organization to receive Simone de Beauvoir Prize for Women\u2019s Freedom.',
#     u'blog': [],
#     u'byline': [],
#     u'document_type': u'article',
#     u'headline': {u'main': u'Museum of Women Gets Freedom Award',
#      u'print_headline': u'Museum of Women Gets Freedom Award'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'organizations',
#       u'rank': u'1',
#       u'value': u'National Museum of Women in the Arts'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Awards, Decorations and Honors'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Women and Girls'}],
#     u'lead_paragraph': u'The National Museum of Women in the Arts will be the first American organization to receive the Simone de Beauvoir Prize for Women\u2019s Freedom.',
#     u'multimedia': [],
#     u'news_desk': u'Culture',
#     u'print_page': u'2',
#     u'pub_date': u'2014-12-24T00:00:00Z',
#     u'section_name': u'Arts',
#     u'snippet': u'The National Museum of Women in the Arts will be the first American organization to receive the Simone de Beauvoir Prize for Women\u2019s Freedom.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Art & Design',
#     u'type_of_material': u'Brief',
#     u'web_url': u'http://www.nytimes.com/2014/12/24/arts/design/museum-of-women-gets-freedom-award.html',
#     u'word_count': u'78'},
#    {u'_id': u'54c1696279881004ea4100a2',
#     u'abstract': u"Friday File column; New York Times archives highlight 1937 and 1954 articles commenting on fact that McSorley's Old Ale House did not allow women to enter; bar remained men-only until Faith Seidenberg won court battle against pub in 1969.",
#     u'blog': [],
#     u'byline': {u'contributor': u'',
#      u'original': u'By MARY JO MURPHY',
#      u'person': [{u'firstname': u'Mary',
#        u'lastname': u'MURPHY',
#        u'middlename': u'Jo',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'main': u'Friday File',
#      u'print_headline': u'Friday File',
#      u'seo': u'Weekend Entertainments From the Archives of The New York Times'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'organizations',
#       u'rank': u'1',
#       u'value': u"McSorley's Old Ale House (Manhattan, NY)"},
#      {u'is_major': u'Y',
#       u'name': u'organizations',
#       u'rank': u'2',
#       u'value': u'New York Times'},
#      {u'is_major': u'Y',
#       u'name': u'persons',
#       u'rank': u'3',
#       u'value': u'Seidenberg, Faith (1923-2015)'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Women and Girls'}],
#     u'lead_paragraph': u'A look at McSorley&#8217;s Old Ale House, and the long time it stood increasingly alone on the wrong side of history. .',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/23/arts/23SUBFRIDAYFILE/23SUBFRIDAYFILE-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/23/arts/23SUBFRIDAYFILE/23SUBFRIDAYFILE-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2015/01/23/arts/23SUBFRIDAYFILE/23SUBFRIDAYFILE-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/23/arts/23SUBFRIDAYFILE/23SUBFRIDAYFILE-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/23/arts/23SUBFRIDAYFILE/23SUBFRIDAYFILE-thumbStandard-v2.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/23/arts/23SUBFRIDAYFILE/23SUBFRIDAYFILE-thumbStandard-v2.jpg',
#       u'width': 75}],
#     u'news_desk': u'Weekend',
#     u'print_page': None,
#     u'pub_date': u'2015-01-23T00:00:00Z',
#     u'section_name': u'N.Y. / Region',
#     u'snippet': u'A look at McSorley&#8217;s Old Ale House, and the long time it stood increasingly alone on the wrong side of history. .',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2015/01/23/nyregion/friday-file.html',
#     u'word_count': u'516'},
#    {u'_id': u'54ac09897988106d7446d5fa',
#     u'abstract': u'Women and men differ substantially in how they engage with online media. These differences may have profound implications for media, gender equality, and even our democracy.',
#     u'blog': [],
#     u'byline': {u'original': u'By EMMA PIERSON',
#      u'person': [{u'firstname': u'Emma',
#        u'lastname': u'PIERSON',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'blogpost',
#     u'headline': {u'kicker': u'Nicholas Kristof',
#      u'main': u'How to Get More Women to Join the Debate'},
#     u'keywords': [{u'name': u'persons',
#       u'rank': u'1',
#       u'value': u'Farrow, Malone (Dylan)'},
#      {u'name': u'organizations', u'rank': u'1', u'value': u'New York Times'},
#      {u'name': u'subject', u'rank': u'1', u'value': u'Women and Girls'}],
#     u'lead_paragraph': None,
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/06/opinion/6kristof_emma/6kristof_emma-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/06/opinion/6kristof_emma/6kristof_emma-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 450,
#       u'legacy': {u'xlarge': u'images/2015/01/06/opinion/6kristof_emma/6kristof_emma-articleLarge.jpg',
#        u'xlargeheight': u'450',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/06/opinion/6kristof_emma/6kristof_emma-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/06/opinion/6kristof_emma/6kristof_emma-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/06/opinion/6kristof_emma/6kristof_emma-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'OpEd',
#     u'print_page': None,
#     u'pub_date': u'2015-01-06T11:11:13Z',
#     u'section_name': u'Opinion',
#     u'snippet': u'Women and men differ substantially in how they engage with online media. These differences may have profound implications for media, gender equality, and even our democracy.',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'Blog',
#     u'web_url': u'http://kristof.blogs.nytimes.com/2015/01/06/how-to-get-more-women-to-join-the-debate/',
#     u'word_count': u'1328'},
#    {u'_id': u'54bc6bf17988107b57cc4dc0',
#     u'abstract': u'Central Illinois Xpress, only basketball team of girls in Springfield, Ill, fifth-grade boys\u2019 league, is 8-1 in first half of season; noteworthy success is due partly to playing more calculated and methodical game than boys (Series: Not the Knicks).',
#     u'blog': [],
#     u'byline': {u'contributor': u'',
#      u'original': u'By SCOTT CACCIOLA',
#      u'person': [{u'firstname': u'Scott',
#        u'lastname': u'CACCIOLA',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'content_kicker': u'Not the Knicks',
#      u'kicker': u'Not the Knicks',
#      u'main': u'Team\u2019s Mission: Beat the Boys (and Maybe Make Them Cry)',
#      u'print_headline': u'Team\u2019s Mission: Beat the Boys (and Maybe Make Them Cry)',
#      u'seo': u'Central Illinois Xpress Emerge as Unlikely Force in Fifth-Grade League'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Basketball'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'2',
#       u'value': u'Springfield (Ill)'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Women and Girls'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Series'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'5',
#       u'value': u'Illinois'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'6',
#       u'value': u'Amateur Athletic Union'},
#      {u'is_major': u'N',
#       u'name': u'organizations',
#       u'rank': u'7',
#       u'value': u'Central Illinois Xpress'}],
#     u'lead_paragraph': u'The Central Illinois Xpress basketball team is the only team of girls in a fifth-grade boys&#8217; league. They have an 8-1 record and aren&#8217;t intimidated.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/19/sports/19notknicks1/19notknicks1-thumbWide.jpg',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/19/sports/19notknicks1/19notknicks1-thumbWide.jpg',
#       u'width': 190},
#      {u'height': 400,
#       u'legacy': {u'xlarge': u'images/2015/01/19/sports/19notknicks1/19notknicks1-articleLarge.jpg',
#        u'xlargeheight': u'400',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/19/sports/19notknicks1/19notknicks1-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/19/sports/19notknicks1/19notknicks1-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/19/sports/19notknicks1/19notknicks1-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Sports',
#     u'print_page': None,
#     u'pub_date': u'2015-01-19T00:00:00Z',
#     u'section_name': u'Sports',
#     u'snippet': u'The Central Illinois Xpress basketball team is the only team of girls in a fifth-grade boys&#8217; league. They have an 8-1 record and aren&#8217;t intimidated.',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2015/01/19/sports/central-illinois-xpress-emerge-as-unlikely-force-in-fifth-grade-league.html',
#     u'word_count': u'1282'},
#    {u'_id': u'515a2a4ffdc59278db001c1e',
#     u'abstract': u'Olympic journey of Noor Hussain Al-Malki, the first Qatari woman to compete in track and field at the Olympics, ends with injury in her 100-meter heat; other results noted.',
#     u'blog': [],
#     u'byline': {u'contributor': u'',
#      u'organization': u'THE ASSOCIATED PRESS',
#      u'original': u'By THE ASSOCIATED PRESS',
#      u'person': []},
#     u'document_type': u'article',
#     u'headline': {u'content_kicker': u'Track | Women',
#      u'main': u'A Triumph for Women From Qatar, Saudi Arabia and Brunei',
#      u'print_headline': u'Triumphant Before Race Even Begins',
#      u'seo': u'For Women From Qatar, Saudi Arabia and Brunei, a Simple Triumph'},
#     u'keywords': [{u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Olympic Games (2012)'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'2',
#       u'value': u'Saudi Arabia'},
#      {u'is_major': u'Y',
#       u'name': u'glocations',
#       u'rank': u'3',
#       u'value': u'Qatar'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'4',
#       u'value': u'Brunei'},
#      {u'is_major': u'Y',
#       u'name': u'subject',
#       u'rank': u'5',
#       u'value': u'Track and Field'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'6',
#       u'value': u'Women and Girls'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'7',
#       u'value': u'Muslims and Islam'}],
#     u'lead_paragraph': u'The conservative Islamic nations were the last countries to enter women in the Olympics, each sending female athletes to London.',
#     u'multimedia': [{u'height': 293,
#       u'legacy': {u'xlarge': u'images/2012/08/04/sports/WOMEN/WOMEN-articleLarge.jpg',
#        u'xlargeheight': u'293',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2012/08/04/sports/WOMEN/WOMEN-articleLarge.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2012/08/04/sports/WOMEN/WOMEN-thumbStandard.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2012/08/04/sports/WOMEN/WOMEN-thumbStandard.jpg',
#       u'width': 75}],
#     u'news_desk': u'Sports',
#     u'print_page': u'3',
#     u'pub_date': u'2012-08-04T00:00:00Z',
#     u'section_name': u'Sports',
#     u'snippet': u'The conservative Islamic nations were the last countries to enter women in the Olympics, each sending female athletes to London.',
#     u'source': u'The New York Times',
#     u'subsection_name': u'Olympics',
#     u'type_of_material': u'News',
#     u'web_url': u'http://www.nytimes.com/2012/08/04/sports/olympics/for-women-from-qatar-saudi-arabia-and-brunei-a-simple-triumph.html',
#     u'word_count': u'335'},
#    {u'_id': u'54ab74c87988106d7446d461',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'original': u'By JOSH KATZ',
#      u'person': [{u'firstname': u'Josh',
#        u'lastname': u'KATZ',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'multimedia',
#     u'headline': {u'kicker': u'The Upshot',
#      u'main': u'How Nonemployed Americans Spend Their Weekdays: Men vs. Women'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'Unemployment'},
#      {u'is_major': u'N',
#       u'name': u'glocations',
#       u'rank': u'2',
#       u'value': u'United States'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Women and Girls'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Men and Boys'}],
#     u'lead_paragraph': u'An interactive comparison of a day in the life of 147 men and 147 women without jobs.',
#     u'multimedia': [{u'height': 126,
#       u'legacy': {u'wide': u'images/2015/01/05/upshot/how-the-nonemployed-spend-their-weekdays-1420042964261/how-the-nonemployed-spend-their-weekdays-1420042964261-thumbWide.png',
#        u'wideheight': u'126',
#        u'widewidth': u'190'},
#       u'subtype': u'wide',
#       u'type': u'image',
#       u'url': u'images/2015/01/05/upshot/how-the-nonemployed-spend-their-weekdays-1420042964261/how-the-nonemployed-spend-their-weekdays-1420042964261-thumbWide.png',
#       u'width': 190},
#      {u'height': 286,
#       u'legacy': {u'xlarge': u'images/2015/01/05/upshot/how-the-nonemployed-spend-their-weekdays-1420042964261/how-the-nonemployed-spend-their-weekdays-1420042964261-articleLarge.png',
#        u'xlargeheight': u'286',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2015/01/05/upshot/how-the-nonemployed-spend-their-weekdays-1420042964261/how-the-nonemployed-spend-their-weekdays-1420042964261-articleLarge.png',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2015/01/05/upshot/how-the-nonemployed-spend-their-weekdays-1420042964261/how-the-nonemployed-spend-their-weekdays-1420042964261-thumbStandard.png',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2015/01/05/upshot/how-the-nonemployed-spend-their-weekdays-1420042964261/how-the-nonemployed-spend-their-weekdays-1420042964261-thumbStandard.png',
#       u'width': 75}],
#     u'news_desk': u'The Upshot',
#     u'print_page': None,
#     u'pub_date': u'2015-01-06T00:00:00Z',
#     u'section_name': u'The Upshot',
#     u'snippet': u'An interactive comparison of a day in the life of 147 men and 147 women without jobs.',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'Interactive Feature',
#     u'web_url': u'http://www.nytimes.com/interactive/2015/01/06/upshot/how-nonemployed-americans-spend-their-weekdays-men-vs-women.html',
#     u'word_count': None},
#    {u'_id': u'53f573897988107411a3895c',
#     u'abstract': None,
#     u'blog': [],
#     u'byline': {u'contributor': u'Lizette Alvarez contributed reporting from New York.',
#      u'original': u'By STEVEN LEE MYERS',
#      u'person': [{u'firstname': u'Steven',
#        u'lastname': u'MYERS',
#        u'middlename': u'Lee',
#        u'organization': u'',
#        u'rank': 1,
#        u'role': u'reported'}]},
#     u'document_type': u'article',
#     u'headline': {u'content_kicker': u'Women at Arms',
#      u'main': u'Living and Fighting Alongside Men, and Fitting In',
#      u'print_headline': u'Living and Fighting Alongside Men, and Fitting In',
#      u'sub': u'Unforeseen Issues ;'},
#     u'keywords': [{u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'1',
#       u'value': u'United States Defense and Military Forces'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'2',
#       u'value': u'Women and Girls'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'3',
#       u'value': u'Iraq War (2003- )'},
#      {u'is_major': u'N',
#       u'name': u'subject',
#       u'rank': u'4',
#       u'value': u'Afghanistan War (2001- )'}],
#     u'lead_paragraph': u'American military women have changed the way the U.S. goes to war \u2014 without the disruption of discipline and unit cohesion that some feared.',
#     u'multimedia': [{u'height': 361,
#       u'legacy': {u'xlarge': u'images/2009/08/17/world/17women.span.600.jpg',
#        u'xlargeheight': u'361',
#        u'xlargewidth': u'600'},
#       u'subtype': u'xlarge',
#       u'type': u'image',
#       u'url': u'images/2009/08/17/world/17women.span.600.jpg',
#       u'width': 600},
#      {u'height': 75,
#       u'legacy': {u'thumbnail': u'images/2009/08/17/world/women.75.7.jpg',
#        u'thumbnailheight': u'75',
#        u'thumbnailwidth': u'75'},
#       u'subtype': u'thumbnail',
#       u'type': u'image',
#       u'url': u'images/2009/08/17/world/women.75.7.jpg',
#       u'width': 75}],
#     u'news_desk': u'Foreign',
#     u'print_page': u'1',
#     u'pub_date': u'2009-08-17T00:00:00Z',
#     u'section_name': u'U.S.',
#     u'snippet': u'American military women have changed the way the U.S. goes to war \u2014 without the disruption of discipline and unit cohesion that some feared.',
#     u'source': u'The New York Times',
#     u'subsection_name': None,
#     u'type_of_material': u'Series',
#     u'web_url': u'http://www.nytimes.com/2009/08/17/us/17women.html',
#     u'word_count': u'2462'}],
#   u'facets': {u'source': {u'terms': [{u'count': 26501,
#       u'term': u'The New York Times'},
#      {u'count': 652, u'term': u'AP'},
#      {u'count': 152, u'term': u'Reuters'}]}},
#   u'meta': {u'hits': 27305, u'offset': 0, u'time': 69}},
#  u'status': u'OK'}

# %%
## Parsing
def parse_articles(articles):
    '''
    This function takes in a response to the NYT api and parses the articles into a list of dictionaries
    '''
    news = []
    for i in articles['response']['docs']:
        dic = {}
        dic['id'] = i['_id']
        if i['abstract'] is not None:
            dic['abstract'] = i['abstract'].encode("utf8")
        dic['headline'] = i['headline']['main'].encode("utf8")
        dic['desk'] = i['news_desk']
        dic['date'] = i['pub_date'][0:10] # we don't need the time of day.
        dic['section'] = i['section_name']
        if i['snippet'] is not None:
            dic['snippet'] = i['snippet'].encode("utf8")
        dic['source'] = i['source']
        dic['type'] = i['type_of_material']
        dic['url'] = i['web_url']
        dic['word_count'] = i['word_count']
        # locations
        locations = []
        for x in range(0,len(i['keywords'])):
            if 'glocations' in i['keywords'][x]['name']:
                locations.append(i['keywords'][x]['value'])
        dic['locations'] = locations
        # subject
        subjects = []
        for x in range(0,len(i['keywords'])):
            if 'subject' in i['keywords'][x]['name']:
                subjects.append(i['keywords'][x]['value'])
        dic['subjects'] = subjects    
        news.append(dic)
    return(news)

# %%
def get_facets(articles):
    ''' 
    Accepts output of NYT api and returns dictionary with source counts
    '''
    source_count = []
    for item in articles['response']['facets']['source']['terms']:
        source = {}
        count = int(item['count'])
        pub = item['term']
        source[pub] = count
        source_count.append(source)
    return(source_count)

# %%
get_facets(articles)
# Out:
# [{u'The New York Times': 26501}, {u'AP': 652}, {u'Reuters': 152}]

# %%
def get_articles(date,query):
    '''
    This function accepts a year in string format (e.g.'1980') and a query (e.g.'Amnesty International') 
    and it will return a list of parsed articles (in dictionaries) for that year.
    '''
    all_articles = []
    for i in range(0,100): #NYT limits pager to first 100 pages. But rarely will you find over 100 pages of results anyway.
        articles = api.search(q = query,
                      fq = {'source':['Reuters','AP', 'The New York Times'],'subject.contains':'women'}, 
                      facet_field='source',
                      begin_date = date + '0101',
                      end_date = date + '1231',
                      facet_filter='true',
                      sort='oldest',
                      page = str(i))
        articles = parse_articles(articles)
        all_articles = all_articles + articles
    return(all_articles)

# %%
women2014 = get_articles('2014','women')

# %%
women = []
for i in range(1980,2014):
    print 'Processing ' + str(i) + '...'
    women_year = get_articles(str(i),'women')
    women = women + women_year
# Out:
# Processing 1980...
# Processing 1981...
# Processing 1982...
# Processing 1983...
# Processing 1984...
# Processing 1985...
# Processing 1986...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-3d9836b9cfc2> in <module>()
#       2 for i in range(1980,2014):
#       3     print 'Processing ' + str(i) + '...'
# ----> 4     women_year = get_articles(str(i),'women')
#       5     women = women + women_year
#
# <ipython-input-8-1ead8225c682> in get_articles(date, query)
#      14                       sort='oldest',
#      15                       page = str(i))
# ---> 16         articles = parse_articles(articles)
#      17         all_articles = all_articles + articles
#      18     return(all_articles)
#
# <ipython-input-5-c5706b748bd4> in parse_articles(articles)
#       5     '''
#       6     news = []
# ----> 7     for i in articles['response']['docs']:
#       8         dic = {}
#       9         dic['id'] = i['_id']
#
# KeyError: 'response'

# %%
import pprint, pickle

# %%
def ld_writeDicts(filePath,dict):  
    f=open(filePath,'w')  
    newData = pickle.dumps(dict, 1)  
    f.write(newData)  
    f.close()

# %%
ld_writeDicts('women-1986',women)

# %%
import csv

# %%
keys = women2014[0].keys()
with open('women2014.csv', 'wb') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(women2014)
